# %%
import mediapipe as mp
import cv2
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import time
import os

# %%
mp_holistic = mp.solutions.holistic
mp_drawing = mp.solutions.drawing_utils

# %%
def mediapip_detection(img,model):
    img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    img.flags.writeable = False
    results = model.process(img)
    img.flags.writeable = True
    img = cv2.cvtColor(img,cv2.COLOR_RGB2BGR)
    return img,results

# %%
def draw_landmarks(img,results):
    mp_drawing.draw_landmarks(img,results.face_landmarks,mp_holistic.FACEMESH_TESSELATION,
                              mp_drawing.DrawingSpec(color=(136,201,3),thickness=1,circle_radius=1),
                              mp_drawing.DrawingSpec(color=(136,220,3),thickness=1,circle_radius=1),
    )
    mp_drawing.draw_landmarks(img,results.pose_landmarks,mp_holistic.POSE_CONNECTIONS,
                              mp_drawing.DrawingSpec(color=(80,22,10),thickness=2,circle_radius=2),
                              mp_drawing.DrawingSpec(color=(80,44,121),thickness=1,circle_radius=1)
    )
    mp_drawing.draw_landmarks(img,results.left_hand_landmarks,mp_holistic.HAND_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(121,22,76),thickness=2,circle_radius=2),
                             mp_drawing.DrawingSpec(color=(121,44,250),thickness=2,circle_radius=2))
    mp_drawing.draw_landmarks(img,results.right_hand_landmarks,mp_holistic.HAND_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(245,117,66),thickness=2,circle_radius=2),
                             mp_drawing.DrawingSpec(color=(245,66,230),thickness=2,circle_radius=2))

# %%
def extract_keypoints(results):
    # hand landmarks - 21*3
    # pose landmarks - 33*4
    # face landmarks - 468*3
    # total = 1662

    pose = np.array([[res.x,res.y,res.z,res.visibility] for res in results.pose_landmarks.landmark ]).flatten() if results.pose_landmarks else np.zeros(33*4)
    lh = np.array([[res.x,res.y,res.z] for res in results.left_hand_landmarks.landmark ]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x,res.y,res.z] for res in results.right_hand_landmarks.landmark ]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    face = np.array([ [res.x,res.y,res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)

    return np.concatenate([pose,lh,rh,face])

# %%
# extract_keypoints(results).shape

# %% [markdown]
# Setup Directories

# %%
data_path = 'mp_data'
no_sequences = 30
sequence_len = 30
actions = ['hello','iloveyou','thanks']

# %%
# for ac in actions:
#     for i in range(no_sequences):
#         try: os.makedirs(os.path.join(data_path,ac,str(i)))
#         except: pass

# %% [markdown]
# Collecting Data

# %%
# cap = cv2.VideoCapture(0)

# with mp_holistic.Holistic() as holistic:
    
#     for action in actions:
#         for seq in range(no_sequences):
#             for frm_no in range(sequence_len):
#                 ret,img = cap.read()
#                 img,results = mediapip_detection(img,holistic)
#                 draw_landmarks(img,results) 

#                 if frm_no == 0:
#                     cv2.putText(img,'STARTING COLLECTION',(120,200),
#                                 cv2.FONT_HERSHEY_SIMPLEX,1,(0,255,0),1,cv2.LINE_AA)
#                     cv2.putText(img,'Collecting frames for {} Video Number {}'.format(action,seq),
#                                 (15,12),cv2.FONT_HERSHEY_SIMPLEX,0.5,(0,0,255),1,cv2.LINE_AA)
#                     cv2.imshow("Image",img)
#                     cv2.waitKey(2000)
#                 else:
#                     cv2.putText(img,'Collecting frames for {} Video Number {}'.format(action,seq),
#                                 (15,12),cv2.FONT_HERSHEY_SIMPLEX,0.5,(0,0,255),1,cv2.LINE_AA)
#                     cv2.imshow("Image",img)
                
#                 keypnts = extract_keypoints(results)
#                 npy_path = os.path.join('mp_data',action,str(seq),str(frm_no))
#                 np.save(npy_path,keypnts)
                
#                 if cv2.waitKey(1) & 0xFF == ord('q'): break
#     cap.release()
#     cv2.destroyAllWindows()

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
label_map = {label:ind for ind,label in enumerate(actions)}
print(label_map)
# Out:
# {'hello': 0, 'iloveyou': 1, 'thanks': 2}

# %%
labels = []
sequences = []

for action in actions:
    for seq in range(no_sequences):
        single_seq = []
        for frm in range(sequence_len):
            res = np.load(os.path.join(data_path,action,str(seq),str(frm)+".npy"))
            single_seq.append(res)
        sequences.append(single_seq)
        labels.append(label_map[action])

# %%
np.array(sequences).shape
print(len(labels))
# Out:
# 90

# %%
X = np.array(sequences)
y = to_categorical(labels).astype(int) # on hot encoding
print(Y.shape,len(labels))
# Out:
# (90, 3) 90

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.05)

# %%
X_train.shape
# Out:
# (85, 30, 1662)

# %% [markdown]
# Build LSTM Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# %%
model = Sequential([
    LSTM(64, return_sequences=True, activation='relu', input_shape=(30,1662)),
    LSTM(128, return_sequences=True, activation='relu'),
    LSTM(64, return_sequences=False, activation='relu'),
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(np.array(actions).shape[0], activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_6 (LSTM)               (None, 30, 64)            442112
#
#  lstm_7 (LSTM)               (None, 30, 128)           98816
#
#  lstm_8 (LSTM)               (None, 64)                49408
#
#  dense_5 (Dense)             (None, 64)                4160
#
#  dense_6 (Dense)             (None, 32)                2080
#
#  dense_7 (Dense)             (None, 3)                 99
#
# =================================================================
# Total params: 596,675
# Trainable params: 596,675
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.fit(X_train, y_train, epochs=200)
# Out:
# Epoch 1/200
# 3/3 [==============================] - 7s 178ms/step - loss: 1.4599 - categorical_accuracy: 0.3294
# Epoch 2/200
# 3/3 [==============================] - 1s 109ms/step - loss: 4.7445 - categorical_accuracy: 0.2471
# Epoch 3/200
# 3/3 [==============================] - 1s 259ms/step - loss: 4.6865 - categorical_accuracy: 0.4235
# Epoch 4/200
# 3/3 [==============================] - 0s 135ms/step - loss: 4.0279 - categorical_accuracy: 0.3294
# Epoch 5/200
# 3/3 [==============================] - 0s 150ms/step - loss: 1.1246 - categorical_accuracy: 0.4353
# Epoch 6/200
# 3/3 [==============================] - 0s 124ms/step - loss: 0.9557 - categorical_accuracy: 0.6000
# Epoch 7/200
# 3/3 [==============================] - 0s 142ms/step - loss: 1.0113 - categorical_accuracy: 0.4471
# Epoch 8/200
# 3/3 [==============================] - 0s 141ms/step - loss: 1.0487 - categorical_accuracy: 0.4588
# Epoch 9/200
# 3/3 [==============================] - 0s 119ms/step - loss: 1.0423 - categorical_accuracy: 0.2706
# Epoch 10/200
# 3/3 [==============================] - 0s 115ms/step - loss: 0.8778 - categorical_accuracy: 0.5529
# Epoch 11/200
# 3/3 [==============================] - 0s 125ms/step - loss: 0.8054 - categorical_accuracy: 0.6471
# Epoch 12/200
# 3/3 [==============================] - 0s 119ms/step - loss: 0.7006 - categorical_accuracy: 0.6471
# Epoch 13/200
# 3/3 [==============================] - 0s 118ms/step - loss: 1.5552 - categorical_accuracy: 0.3059
# Epoch 14/200
# 3/3 [==============================] - 0s 120ms/step - loss: 1.2440 - categorical_accuracy: 0.4471
# Epoch 15/200
# 3/3 [==============================] - 0s 136ms/step - loss: 1.0655 - categorical_accuracy: 0.3412
# Epoch 16/200
# 3/3 [==============================] - 1s 219ms/step - loss: 1.0530 - categorical_accuracy: 0.4941
# Epoch 17/200
# 3/3 [==============================] - 0s 135ms/step - loss: 0.9926 - categorical_accuracy: 0.4471
# Epoch 18/200
# 3/3 [==============================] - 0s 149ms/step - loss: 0.8126 - categorical_accuracy: 0.7412
# Epoch 19/200
# 3/3 [==============================] - 0s 122ms/step - loss: 0.6827 - categorical_accuracy: 0.7294
# Epoch 20/200
# 3/3 [==============================] - 0s 150ms/step - loss: 0.7143 - categorical_accuracy: 0.6941
# Epoch 21/200
# 3/3 [==============================] - 0s 138ms/step - loss: 0.7286 - categorical_accuracy: 0.6706
# Epoch 22/200
# 3/3 [==============================] - 0s 111ms/step - loss: 0.8340 - categorical_accuracy: 0.5882
# Epoch 23/200
# 3/3 [==============================] - 0s 136ms/step - loss: 0.8497 - categorical_accuracy: 0.5529
# Epoch 24/200
# 3/3 [==============================] - 0s 156ms/step - loss: 0.8108 - categorical_accuracy: 0.6824
# Epoch 25/200
# 3/3 [==============================] - 0s 138ms/step - loss: 0.6606 - categorical_accuracy: 0.7412
# Epoch 26/200
# 3/3 [==============================] - 0s 125ms/step - loss: 0.5086 - categorical_accuracy: 0.7882
# Epoch 27/200
# 3/3 [==============================] - 0s 161ms/step - loss: 0.4987 - categorical_accuracy: 0.7882
# Epoch 28/200
# 3/3 [==============================] - 0s 174ms/step - loss: 0.4973 - categorical_accuracy: 0.8235
# Epoch 29/200
# 3/3 [==============================] - 0s 145ms/step - loss: 0.3493 - categorical_accuracy: 0.9059
# Epoch 30/200
# 3/3 [==============================] - 0s 142ms/step - loss: 0.2362 - categorical_accuracy: 0.9412
# Epoch 31/200
# 3/3 [==============================] - 0s 129ms/step - loss: 0.1677 - categorical_accuracy: 0.9765
# Epoch 32/200
# 3/3 [==============================] - 1s 176ms/step - loss: 0.1350 - categorical_accuracy: 0.9647
# Epoch 33/200
# 3/3 [==============================] - 0s 113ms/step - loss: 0.0854 - categorical_accuracy: 0.9765
# Epoch 34/200
# 3/3 [==============================] - 0s 116ms/step - loss: 0.0736 - categorical_accuracy: 0.9882
# Epoch 35/200
# 3/3 [==============================] - 0s 122ms/step - loss: 0.0635 - categorical_accuracy: 0.9882
# Epoch 36/200
# 3/3 [==============================] - 0s 125ms/step - loss: 0.1376 - categorical_accuracy: 0.9647
# Epoch 37/200
# 3/3 [==============================] - 0s 121ms/step - loss: 2.0828 - categorical_accuracy: 0.6235
# Epoch 38/200
# 3/3 [==============================] - 0s 145ms/step - loss: 0.9953 - categorical_accuracy: 0.5647
# Epoch 39/200
# 3/3 [==============================] - 0s 117ms/step - loss: 0.8026 - categorical_accuracy: 0.5647
# Epoch 40/200
# 3/3 [==============================] - 0s 140ms/step - loss: 0.7745 - categorical_accuracy: 0.6353
# Epoch 41/200
# 3/3 [==============================] - 0s 140ms/step - loss: 0.5910 - categorical_accuracy: 0.7294
# Epoch 42/200
# 3/3 [==============================] - 0s 121ms/step - loss: 0.4577 - categorical_accuracy: 0.8588
# Epoch 43/200
# 3/3 [==============================] - 0s 116ms/step - loss: 0.3054 - categorical_accuracy: 0.9176
# Epoch 44/200
# 3/3 [==============================] - 0s 133ms/step - loss: 0.6295 - categorical_accuracy: 0.6941
# Epoch 45/200
# 3/3 [==============================] - 0s 129ms/step - loss: 0.3599 - categorical_accuracy: 0.8353
# Epoch 46/200
# 3/3 [==============================] - 0s 124ms/step - loss: 0.4658 - categorical_accuracy: 0.7882
# Epoch 47/200
# 3/3 [==============================] - 0s 119ms/step - loss: 0.7645 - categorical_accuracy: 0.7294
# Epoch 48/200
# 3/3 [==============================] - 0s 116ms/step - loss: 0.4644 - categorical_accuracy: 0.7765
# Epoch 49/200
# 3/3 [==============================] - 0s 116ms/step - loss: 0.4685 - categorical_accuracy: 0.8471
# Epoch 50/200
# 3/3 [==============================] - 0s 127ms/step - loss: 0.3736 - categorical_accuracy: 0.8588
# Epoch 51/200
# 3/3 [==============================] - 0s 122ms/step - loss: 0.2205 - categorical_accuracy: 0.9647
# Epoch 52/200
# 3/3 [==============================] - 0s 120ms/step - loss: 0.2188 - categorical_accuracy: 0.9765
# Epoch 53/200
# 3/3 [==============================] - 0s 114ms/step - loss: 0.1364 - categorical_accuracy: 0.9647
# Epoch 54/200
# 3/3 [==============================] - 0s 114ms/step - loss: 0.1603 - categorical_accuracy: 0.9529
# Epoch 55/200
# 3/3 [==============================] - 0s 115ms/step - loss: 0.1980 - categorical_accuracy: 0.9059
# Epoch 56/200
# 3/3 [==============================] - 0s 122ms/step - loss: 0.1283 - categorical_accuracy: 0.9765
# Epoch 57/200
# 3/3 [==============================] - 0s 130ms/step - loss: 0.1556 - categorical_accuracy: 0.9294
# Epoch 58/200
# 3/3 [==============================] - 0s 115ms/step - loss: 0.1761 - categorical_accuracy: 0.9529
# Epoch 59/200
# 3/3 [==============================] - 0s 126ms/step - loss: 0.1667 - categorical_accuracy: 0.9529
# Epoch 60/200
# 3/3 [==============================] - 0s 118ms/step - loss: 0.0997 - categorical_accuracy: 0.9882
# Epoch 61/200
# 3/3 [==============================] - 0s 119ms/step - loss: 0.1127 - categorical_accuracy: 0.9765
# Epoch 62/200
# 3/3 [==============================] - 0s 122ms/step - loss: 0.0749 - categorical_accuracy: 0.9882
# Epoch 63/200
# 3/3 [==============================] - 0s 112ms/step - loss: 0.0626 - categorical_accuracy: 0.9882
# Epoch 64/200
# 3/3 [==============================] - 0s 134ms/step - loss: 0.0722 - categorical_accuracy: 0.9765
# Epoch 65/200
# 3/3 [==============================] - 0s 131ms/step - loss: 0.0634 - categorical_accuracy: 0.9882
# Epoch 66/200
# 3/3 [==============================] - 0s 124ms/step - loss: 0.0604 - categorical_accuracy: 0.9882
# Epoch 67/200
# 3/3 [==============================] - 0s 118ms/step - loss: 0.0510 - categorical_accuracy: 0.9882
# Epoch 68/200
# 3/3 [==============================] - 0s 113ms/step - loss: 0.0514 - categorical_accuracy: 0.9882
# Epoch 69/200
# 3/3 [==============================] - 0s 112ms/step - loss: 0.0514 - categorical_accuracy: 0.9882
# Epoch 70/200
# 3/3 [==============================] - 0s 112ms/step - loss: 0.0490 - categorical_accuracy: 0.9882
# Epoch 71/200
# 3/3 [==============================] - 0s 123ms/step - loss: 0.0489 - categorical_accuracy: 0.9882
# Epoch 72/200
# 3/3 [==============================] - 0s 123ms/step - loss: 0.0480 - categorical_accuracy: 0.9882
# Epoch 73/200
# 3/3 [==============================] - 0s 124ms/step - loss: 0.0491 - categorical_accuracy: 0.9882
# Epoch 74/200
# 3/3 [==============================] - 0s 118ms/step - loss: 0.0459 - categorical_accuracy: 0.9882
# Epoch 75/200
# 3/3 [==============================] - 0s 121ms/step - loss: 0.0455 - categorical_accuracy: 0.9882
# Epoch 76/200
# 3/3 [==============================] - 0s 145ms/step - loss: 0.0446 - categorical_accuracy: 0.9882
# Epoch 77/200
# 3/3 [==============================] - 0s 123ms/step - loss: 0.0448 - categorical_accuracy: 0.9882
# Epoch 78/200
# 3/3 [==============================] - 0s 122ms/step - loss: 0.0461 - categorical_accuracy: 0.9882
# Epoch 79/200
# 3/3 [==============================] - 0s 121ms/step - loss: 0.0456 - categorical_accuracy: 0.9882
# Epoch 80/200
# 3/3 [==============================] - 0s 116ms/step - loss: 0.0432 - categorical_accuracy: 0.9882
# Epoch 81/200
# 3/3 [==============================] - 0s 125ms/step - loss: 0.0445 - categorical_accuracy: 0.9882
# Epoch 82/200
# 3/3 [==============================] - 0s 119ms/step - loss: 0.0480 - categorical_accuracy: 0.9882
# Epoch 83/200
# 3/3 [==============================] - 0s 125ms/step - loss: 0.0430 - categorical_accuracy: 0.9882
# Epoch 84/200
# 3/3 [==============================] - 0s 126ms/step - loss: 0.0454 - categorical_accuracy: 0.9882
# Epoch 85/200
# 3/3 [==============================] - 0s 113ms/step - loss: 0.0427 - categorical_accuracy: 0.9882
# Epoch 86/200
# 3/3 [==============================] - 0s 126ms/step - loss: 0.0431 - categorical_accuracy: 0.9882
# Epoch 87/200
# 3/3 [==============================] - 0s 124ms/step - loss: 0.0419 - categorical_accuracy: 0.9882
# Epoch 88/200
# 3/3 [==============================] - 0s 122ms/step - loss: 0.0384 - categorical_accuracy: 0.9882
# Epoch 89/200
# 3/3 [==============================] - 0s 112ms/step - loss: 0.0392 - categorical_accuracy: 0.9882
# Epoch 90/200
# 3/3 [==============================] - 0s 112ms/step - loss: 0.0418 - categorical_accuracy: 0.9882
# Epoch 91/200
# 3/3 [==============================] - 0s 122ms/step - loss: 0.0411 - categorical_accuracy: 0.9882
# Epoch 92/200
# 3/3 [==============================] - 0s 119ms/step - loss: 0.0446 - categorical_accuracy: 0.9882
# Epoch 93/200
# 3/3 [==============================] - 0s 130ms/step - loss: 0.0444 - categorical_accuracy: 0.9882
# Epoch 94/200
# 3/3 [==============================] - 0s 128ms/step - loss: 0.0402 - categorical_accuracy: 0.9882
# Epoch 95/200
# 3/3 [==============================] - 0s 114ms/step - loss: 0.0420 - categorical_accuracy: 0.9882
# Epoch 96/200
# 3/3 [==============================] - 0s 123ms/step - loss: 0.0380 - categorical_accuracy: 0.9882
# Epoch 97/200
# 3/3 [==============================] - 0s 127ms/step - loss: 0.0401 - categorical_accuracy: 0.9882
# Epoch 98/200
# 3/3 [==============================] - 0s 123ms/step - loss: 0.0340 - categorical_accuracy: 0.9882
# Epoch 99/200
# 3/3 [==============================] - 0s 112ms/step - loss: 0.0387 - categorical_accuracy: 0.9882
# Epoch 100/200
# 3/3 [==============================] - 0s 113ms/step - loss: 0.0427 - categorical_accuracy: 0.9882
# Epoch 101/200
# 3/3 [==============================] - 0s 125ms/step - loss: 0.0410 - categorical_accuracy: 0.9882
# Epoch 102/200
# 3/3 [==============================] - 0s 130ms/step - loss: 0.0351 - categorical_accuracy: 0.9882
# Epoch 103/200
# 3/3 [==============================] - 0s 119ms/step - loss: 0.0349 - categorical_accuracy: 0.9882
# Epoch 104/200
# 3/3 [==============================] - 0s 118ms/step - loss: 0.0340 - categorical_accuracy: 0.9882
# Epoch 105/200
# 3/3 [==============================] - 0s 114ms/step - loss: 0.0339 - categorical_accuracy: 0.9882
# Epoch 106/200
# 3/3 [==============================] - 0s 120ms/step - loss: 0.0350 - categorical_accuracy: 0.9882
# Epoch 107/200
# 3/3 [==============================] - 0s 115ms/step - loss: 0.0335 - categorical_accuracy: 0.9882
# Epoch 108/200
# 3/3 [==============================] - 0s 123ms/step - loss: 0.0418 - categorical_accuracy: 0.9882
# Epoch 109/200
# 3/3 [==============================] - 0s 123ms/step - loss: 0.0279 - categorical_accuracy: 0.9882
# Epoch 110/200
# 3/3 [==============================] - 0s 111ms/step - loss: 0.0388 - categorical_accuracy: 0.9882
# Epoch 111/200
# 3/3 [==============================] - 0s 118ms/step - loss: 0.0371 - categorical_accuracy: 0.9882
# Epoch 112/200
# 3/3 [==============================] - 0s 119ms/step - loss: 0.0296 - categorical_accuracy: 0.9882
# Epoch 113/200
# 3/3 [==============================] - 0s 125ms/step - loss: 0.0406 - categorical_accuracy: 0.9882
# Epoch 114/200
# 3/3 [==============================] - 0s 114ms/step - loss: 0.0294 - categorical_accuracy: 0.9882
# Epoch 115/200
# 3/3 [==============================] - 0s 120ms/step - loss: 2.0197 - categorical_accuracy: 0.7765
# Epoch 116/200
# 3/3 [==============================] - 0s 113ms/step - loss: 2.6682 - categorical_accuracy: 0.3882
# Epoch 117/200
# 3/3 [==============================] - 0s 125ms/step - loss: 1.1484 - categorical_accuracy: 0.3647
# Epoch 118/200
# 3/3 [==============================] - 0s 121ms/step - loss: 0.9589 - categorical_accuracy: 0.4588
# Epoch 119/200
# 3/3 [==============================] - 0s 123ms/step - loss: 0.7716 - categorical_accuracy: 0.5765
# Epoch 120/200
# 3/3 [==============================] - 0s 113ms/step - loss: 0.5391 - categorical_accuracy: 0.8118
# Epoch 121/200
# 3/3 [==============================] - 0s 119ms/step - loss: 0.6376 - categorical_accuracy: 0.6824
# Epoch 122/200
# 3/3 [==============================] - 0s 121ms/step - loss: 0.3976 - categorical_accuracy: 0.8706
# Epoch 123/200
# 3/3 [==============================] - 0s 117ms/step - loss: 0.2679 - categorical_accuracy: 0.8941
# Epoch 124/200
# 3/3 [==============================] - 0s 118ms/step - loss: 0.2136 - categorical_accuracy: 0.9412
# Epoch 125/200
# 3/3 [==============================] - 0s 115ms/step - loss: 0.2202 - categorical_accuracy: 0.9412
# Epoch 126/200
# 3/3 [==============================] - 0s 115ms/step - loss: 0.1499 - categorical_accuracy: 0.9882
# Epoch 127/200
# 3/3 [==============================] - 0s 116ms/step - loss: 0.1566 - categorical_accuracy: 0.9529
# Epoch 128/200
# 3/3 [==============================] - 0s 123ms/step - loss: 0.1850 - categorical_accuracy: 0.9059
# Epoch 129/200
# 3/3 [==============================] - 0s 130ms/step - loss: 0.2583 - categorical_accuracy: 0.9647
# Epoch 130/200
# 3/3 [==============================] - 0s 123ms/step - loss: 0.2074 - categorical_accuracy: 0.9294
# Epoch 131/200
# 3/3 [==============================] - 0s 116ms/step - loss: 0.0989 - categorical_accuracy: 0.9882
# Epoch 132/200
# 3/3 [==============================] - 0s 113ms/step - loss: 0.1084 - categorical_accuracy: 0.9882
# Epoch 133/200
# 3/3 [==============================] - 0s 128ms/step - loss: 0.1125 - categorical_accuracy: 0.9765
# Epoch 134/200
# 3/3 [==============================] - 0s 118ms/step - loss: 0.0522 - categorical_accuracy: 0.9882
# Epoch 135/200
# 3/3 [==============================] - 0s 130ms/step - loss: 0.0593 - categorical_accuracy: 0.9882
# Epoch 136/200
# 3/3 [==============================] - 0s 114ms/step - loss: 0.0677 - categorical_accuracy: 0.9882
# Epoch 137/200
# 3/3 [==============================] - 0s 111ms/step - loss: 0.0494 - categorical_accuracy: 0.9882
# Epoch 138/200
# 3/3 [==============================] - 0s 128ms/step - loss: 0.0368 - categorical_accuracy: 0.9882
# Epoch 139/200
# 3/3 [==============================] - 0s 122ms/step - loss: 0.0396 - categorical_accuracy: 0.9882
# Epoch 140/200
# 3/3 [==============================] - 0s 128ms/step - loss: 0.0781 - categorical_accuracy: 0.9882
# Epoch 141/200
# 3/3 [==============================] - 0s 115ms/step - loss: 0.0596 - categorical_accuracy: 0.9647
# Epoch 142/200
# 3/3 [==============================] - 0s 124ms/step - loss: 0.0598 - categorical_accuracy: 0.9882
# Epoch 143/200
# 3/3 [==============================] - 0s 126ms/step - loss: 0.0610 - categorical_accuracy: 0.9765
# Epoch 144/200
# 3/3 [==============================] - 0s 120ms/step - loss: 0.0502 - categorical_accuracy: 0.9765
# Epoch 145/200
# 3/3 [==============================] - 0s 120ms/step - loss: 0.0641 - categorical_accuracy: 0.9765
# Epoch 146/200
# 3/3 [==============================] - 0s 115ms/step - loss: 0.0908 - categorical_accuracy: 0.9647
# Epoch 147/200
# 3/3 [==============================] - 0s 126ms/step - loss: 0.5755 - categorical_accuracy: 0.8824
# Epoch 148/200
# 3/3 [==============================] - 0s 125ms/step - loss: 1.8774 - categorical_accuracy: 0.5059
# Epoch 149/200
# 3/3 [==============================] - 0s 120ms/step - loss: 0.9507 - categorical_accuracy: 0.4353
# Epoch 150/200
# 3/3 [==============================] - 0s 129ms/step - loss: 0.8666 - categorical_accuracy: 0.6941
# Epoch 151/200
# 3/3 [==============================] - 0s 127ms/step - loss: 0.7184 - categorical_accuracy: 0.7647
# Epoch 152/200
# 3/3 [==============================] - 0s 123ms/step - loss: 0.9161 - categorical_accuracy: 0.7176
# Epoch 153/200
# 3/3 [==============================] - 0s 121ms/step - loss: 0.4202 - categorical_accuracy: 0.8588
# Epoch 154/200
# 3/3 [==============================] - 0s 124ms/step - loss: 0.6333 - categorical_accuracy: 0.7647
# Epoch 155/200
# 3/3 [==============================] - 0s 125ms/step - loss: 0.4621 - categorical_accuracy: 0.8235
# Epoch 156/200
# 3/3 [==============================] - 0s 114ms/step - loss: 0.4019 - categorical_accuracy: 0.9765
# Epoch 157/200
# 3/3 [==============================] - 0s 115ms/step - loss: 0.2462 - categorical_accuracy: 0.9412
# Epoch 158/200
# 3/3 [==============================] - 0s 115ms/step - loss: 0.2265 - categorical_accuracy: 0.9294
# Epoch 159/200
# 3/3 [==============================] - 0s 128ms/step - loss: 0.2202 - categorical_accuracy: 0.9529
# Epoch 160/200
# 3/3 [==============================] - 0s 126ms/step - loss: 0.1133 - categorical_accuracy: 0.9765
# Epoch 161/200
# 3/3 [==============================] - 0s 114ms/step - loss: 0.1259 - categorical_accuracy: 0.9647
# Epoch 162/200
# 3/3 [==============================] - 0s 113ms/step - loss: 0.1167 - categorical_accuracy: 0.9765
# Epoch 163/200
# 3/3 [==============================] - 0s 113ms/step - loss: 0.0808 - categorical_accuracy: 0.9765
# Epoch 164/200
# 3/3 [==============================] - 0s 126ms/step - loss: 0.0949 - categorical_accuracy: 0.9765
# Epoch 165/200
# 3/3 [==============================] - 0s 126ms/step - loss: 0.1238 - categorical_accuracy: 0.9647
# Epoch 166/200
# 3/3 [==============================] - 0s 116ms/step - loss: 0.2045 - categorical_accuracy: 0.9176
# Epoch 167/200
# 3/3 [==============================] - 0s 115ms/step - loss: 0.1318 - categorical_accuracy: 0.9882
# Epoch 168/200
# 3/3 [==============================] - 0s 124ms/step - loss: 0.1577 - categorical_accuracy: 0.9412
# Epoch 169/200
# 3/3 [==============================] - 0s 126ms/step - loss: 0.0659 - categorical_accuracy: 0.9882
# Epoch 170/200
# 3/3 [==============================] - 0s 121ms/step - loss: 0.1337 - categorical_accuracy: 0.9647
# Epoch 171/200
# 3/3 [==============================] - 0s 117ms/step - loss: 0.2762 - categorical_accuracy: 0.9176
# Epoch 172/200
# 3/3 [==============================] - 0s 119ms/step - loss: 0.1990 - categorical_accuracy: 0.9176
# Epoch 173/200
# 3/3 [==============================] - 0s 117ms/step - loss: 0.2225 - categorical_accuracy: 0.9059
# Epoch 174/200
# 3/3 [==============================] - 0s 123ms/step - loss: 0.1275 - categorical_accuracy: 0.9529
# Epoch 175/200
# 3/3 [==============================] - 0s 121ms/step - loss: 0.2218 - categorical_accuracy: 0.9294
# Epoch 176/200
# 3/3 [==============================] - 0s 116ms/step - loss: 0.1951 - categorical_accuracy: 0.9647
# Epoch 177/200
# 3/3 [==============================] - 0s 114ms/step - loss: 0.1211 - categorical_accuracy: 0.9765
# Epoch 178/200
# 3/3 [==============================] - 0s 122ms/step - loss: 0.0826 - categorical_accuracy: 0.9765
# Epoch 179/200
# 3/3 [==============================] - 0s 119ms/step - loss: 0.0705 - categorical_accuracy: 0.9765
# Epoch 180/200
# 3/3 [==============================] - 0s 122ms/step - loss: 0.0674 - categorical_accuracy: 0.9529
# Epoch 181/200
# 3/3 [==============================] - 0s 121ms/step - loss: 0.0470 - categorical_accuracy: 0.9647
# Epoch 182/200
# 3/3 [==============================] - 0s 115ms/step - loss: 0.0497 - categorical_accuracy: 0.9882
# Epoch 183/200
# 3/3 [==============================] - 0s 111ms/step - loss: 0.0457 - categorical_accuracy: 0.9765
# Epoch 184/200
# 3/3 [==============================] - 0s 117ms/step - loss: 0.0347 - categorical_accuracy: 0.9882
# Epoch 185/200
# 3/3 [==============================] - 0s 118ms/step - loss: 0.0366 - categorical_accuracy: 0.9882
# Epoch 186/200
# 3/3 [==============================] - 0s 122ms/step - loss: 0.0321 - categorical_accuracy: 0.9882
# Epoch 187/200
# 3/3 [==============================] - 0s 111ms/step - loss: 0.0275 - categorical_accuracy: 0.9882
# Epoch 188/200
# 3/3 [==============================] - 0s 113ms/step - loss: 0.0263 - categorical_accuracy: 0.9882
# Epoch 189/200
# 3/3 [==============================] - 0s 140ms/step - loss: 0.0231 - categorical_accuracy: 0.9882
# Epoch 190/200
# 3/3 [==============================] - 0s 127ms/step - loss: 0.0203 - categorical_accuracy: 0.9882
# Epoch 191/200
# 3/3 [==============================] - 0s 119ms/step - loss: 0.0176 - categorical_accuracy: 0.9882
# Epoch 192/200
# 3/3 [==============================] - 0s 119ms/step - loss: 0.0190 - categorical_accuracy: 0.9882
# Epoch 193/200
# 3/3 [==============================] - 0s 119ms/step - loss: 0.0169 - categorical_accuracy: 0.9882
# Epoch 194/200
# 3/3 [==============================] - 0s 113ms/step - loss: 0.0140 - categorical_accuracy: 1.0000
# Epoch 195/200
# 3/3 [==============================] - 0s 124ms/step - loss: 0.0713 - categorical_accuracy: 0.9647
# Epoch 196/200
# 3/3 [==============================] - 0s 132ms/step - loss: 0.0192 - categorical_accuracy: 0.9882
# Epoch 197/200
# 3/3 [==============================] - 0s 125ms/step - loss: 0.1459 - categorical_accuracy: 0.9765
# Epoch 198/200
# 3/3 [==============================] - 0s 117ms/step - loss: 0.1259 - categorical_accuracy: 0.9529
# Epoch 199/200
# 3/3 [==============================] - 0s 116ms/step - loss: 0.2200 - categorical_accuracy: 0.8941
# Epoch 200/200
# 3/3 [==============================] - 0s 121ms/step - loss: 0.1154 - categorical_accuracy: 0.9765

# %%
model.save('lstmmodel.h5')

# %%
y_pred = model.predict(X_test)
# y_pred = [y_pred.index(max(y_pred)) for x in y_pred]
print(y_pred)
print(y_test)
# Out:
# 1/1 [==============================] - 1s 1s/step
# [[9.9940312e-01 5.9680414e-04 6.7778615e-08]
#  [2.2588654e-06 1.9836156e-03 9.9801409e-01]
#  [4.1308926e-08 7.9586440e-05 9.9992037e-01]
#  [3.5455322e-01 6.3996631e-01 5.4804925e-03]
#  [4.2956229e-03 9.2359227e-01 7.2112121e-02]]
# [[1 0 0]
#  [0 0 1]
#  [0 0 1]
#  [0 1 0]
#  [0 1 0]]

# %%
model = tf.keras.models.load_model('lstmmodel.h5')

# %% [markdown]
# Real Time Action Detection

# %%
from scipy import stats

# %%
colors = [(245,117,16),(117,245,16),(16,117,245)]

def prob_viz(res,actions,img):
    for ind,prob in enumerate(res):
        cv2.rectangle(img,(0,60 + ind*40),(int(prob*100),90+ind*40),colors[ind],-1)
        cv2.putText(img,actions[ind],(0,85+ind*40),cv2.FONT_HERSHEY_SIMPLEX,1,(255,255,255),2,cv2.LINE_AA)

# %%
res = []
cam = cv2.VideoCapture(0)
sequence = []
threshold = 0.7
preds = []

with mp_holistic.Holistic() as holistic:
    
    while cam.isOpened():
        ret,img = cam.read()

        img,results = mediapip_detection(img,holistic)
        draw_landmarks(img,results)
        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-30:]

        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence,axis=0))[0]
            preds.append(np.argmax(res))
        
        # if np.unique(preds[-10:])[0] == np.argmax(res):
        #     if res[np.argmax(res)] > threshold:

        prob_viz(res,actions,img)
        cv2.imshow("Image - ",img)

        if cv2.waitKey(1) & 0xFF == ord('q'): break

cam.release()
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 1s 622ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 29ms/step
